# %% [markdown]
# # Impfraten bei Kindern ccc
#
# Gruppe: Léa Grandchamp, Brigit Marxe, Enea Solca
#
# Fragen
#
# - Wie haben sich die Durchimpfungsraten für zentrale Kinderimpfungen im Beobachtungszeitraum des Datensatzes entwickelt, und in welchen ausgewählten Ländern oder Weltregionen zeigen sich besonders starke Fortschritte bzw. Rückschritte?
# - Gibt es systematische Unterschiede in der Höhe der Durchimpfungsraten zwischen verschiedenen Kinderimpfungen, und haben sich diese Unterschiede im Zeitverlauf vergrössert oder verkleinert?
# - Lässt sich ein Zusammenhang zwischen den Durchimpfungsraten und der Kindersterblichkeit erstellen?
#
# Quellen:
# - https://ourworldindata.org/grapher/global-vaccination-coverage
# - https://ourworldindata.org/child-mortality

# %% [markdown]
# ## 1. Daten beschaffen und laden

# %%
# lade deine Bibliotheken -> Pandas, Seaborn, Matplotlib sind die wichtigsten für diese Aufgaben

import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 # lade deine Bibliotheken -> Pandas, Seaborn, Matplotlib sind die wichtigsten für diese Aufgaben
#       3 import pandas as pd
# ----> 4 import seaborn as sns
#       5 from matplotlib import pyplot as plt
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\seaborn\__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\seaborn\rcmod.py:3
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ----> 3 import matplotlib as mpl
#       4 from cycler import cycler
#       5 from . import palettes
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
#      25 from matplotlib import _api, cbook
# ---> 26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\matplotlib\backends\__init__.py:1
# ----> 1 from .registry import BackendFilter, backend_registry  # noqa: F401
#       3 # NOTE: plt.switch_backend() (called at import time) will add a "backend"
#       4 # attribute here for backcompat.
#       5 _QT_FORCE_QT5_BINDING = False
#
# ModuleNotFoundError: No module named 'matplotlib.backends.registry'

# %%
df1 = pd.read_csv("global-vaccination-coverage.csv", skiprows=1, names=["Entity","Code","Year","Share of one-year-olds who have had three doses of the hepatitis B vaccine","Share of one-year-olds vaccinated against Haemophilus influenzae type b","Share of one-year-olds who have had the one dose of the inactivated polio vaccine","Share of one-year-olds who have had one dose of the measles vaccine","Share of one-year-olds who have had the third dose of the pneumococcal conjugate vaccine","Share of one-year-olds who have had three doses of the polio vaccine","Share of one-year-olds vaccinated against rubella","Share of one-year-olds vaccinated against rotavirus","Share of one-year-olds who have had three doses of the diphtheria, tetanus and pertussis vaccine"])
                 
df1.head(10000)
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2007
# 1     Afghanistan  AFG  2008
# 2     Afghanistan  AFG  2009
# 3     Afghanistan  AFG  2010
# 4     Afghanistan  AFG  2011
# ...           ...  ...   ...
# 9198     Zimbabwe  ZWE  1990
# 9199     Zimbabwe  ZWE  1991
# 9200     Zimbabwe  ZWE  1992
# 9201     Zimbabwe  ZWE  1993
# 9202     Zimbabwe  ZWE  1994
#
#       Share of one-year-olds who have had three doses of the hepatitis B vaccine  \
# 0                                                  63.0
# 1                                                  64.0
# 2                                                  63.0
# 3                                                  66.0
# 4                                                  68.0
# ...                                                 ...
# 9198                                                NaN
# 9199                                                NaN
# 9200                                                NaN
# 9201                                                NaN
# 9202                                                NaN
#
#       Share of one-year-olds vaccinated against Haemophilus influenzae type b  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  63.0
# 3                                                  66.0
# 4                                                  68.0
# ...                                                 ...
# 9198                                                NaN
# 9199                                                NaN
# 9200                                                NaN
# 9201                                                NaN
# 9202                                                NaN
#
#       Share of one-year-olds who have had the one dose of the inactivated polio vaccine  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9198                                                NaN
# 9199                                                NaN
# 9200                                                NaN
# 9201                                                NaN
# 9202                                                NaN
#
#       Share of one-year-olds who have had one dose of the measles vaccine  \
# 0                                                  55.0
# 1                                                  59.0
# 2                                                  60.0
# 3                                                  62.0
# 4                                                  64.0
# ...                                                 ...
# 9198                                               87.0
# 9199                                               87.0
# 9200                                               86.0
# 9201                                               86.0
# 9202                                               87.0
#
#       Share of one-year-olds who have had the third dose of the pneumococcal conjugate vaccine  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9198                                                NaN
# 9199                                                NaN
# 9200                                                NaN
# 9201                                                NaN
# 9202                                                NaN
#
#       Share of one-year-olds who have had three doses of the polio vaccine  \
# 0                                                  63.0
# 1                                                  64.0
# 2                                                  63.0
# 3                                                  66.0
# 4                                                  68.0
# ...                                                 ...
# 9198                                               89.0
# 9199                                               88.0
# 9200                                               86.0
# 9201                                               85.0
# 9202                                               87.0
#
#       Share of one-year-olds vaccinated against rubella  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9198                                                NaN
# 9199                                                NaN
# 9200                                                NaN
# 9201                                                NaN
# 9202                                                NaN
#
#       Share of one-year-olds vaccinated against rotavirus  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9198                                                NaN
# 9199                                                NaN
# 9200                                                NaN
# 9201                                                NaN
# 9202                                                NaN
#
#       Share of one-year-olds who have had three doses of the diphtheria, tetanus and pertussis vaccine
# 0                                                  63.0
# 1                                                  64.0
# 2                                                  63.0
# 3                                                  66.0
# 4                                                  68.0
# ...                                                 ...
# 9198                                               88.0
# 9199                                               87.0
# 9200                                               86.0
# 9201                                               85.0
# 9202                                               87.0
#
# [9203 rows x 12 columns]

# %%
df2 = pd.read_csv("child-mortality.csv", skiprows=1, names=["Entity","Code","Year","Child mortality rate"])
df2.head(100000)
# Out:
#             Entity Code  Year  Child mortality rate
# 0      Afghanistan  AFG  1957                 37.13
# 1      Afghanistan  AFG  1958                 36.52
# 2      Afghanistan  AFG  1959                 35.95
# 3      Afghanistan  AFG  1960                 35.32
# 4      Afghanistan  AFG  1961                 34.76
# ...            ...  ...   ...                   ...
# 16830     Zimbabwe  ZWE  2019                  5.11
# 16831     Zimbabwe  ZWE  2020                  5.01
# 16832     Zimbabwe  ZWE  2021                  4.76
# 16833     Zimbabwe  ZWE  2022                  4.60
# 16834     Zimbabwe  ZWE  2023                  4.42
#
# [16835 rows x 4 columns]

# %% [markdown]
# ## 2. Daten vorbereiten
# - Die Roh-Daten sind bereits im Long-Format
# - Für die Analyse werden die Daten pivotiert: Jede Spalte repräsentiert eine Region, die Zeilen sind die verschiedenen Jahre - in absteigender Reihenfolge.

# %%
df1_pivot = df1.pivot(index='Entity', columns='Year', values='Share of one-year-olds who have had three doses of the hepatitis B vaccine')
df1_pivot.head(100000)
# Out:
# Year                   1980  1981  1982  1983  1984  1985  1986  1987  1988  \
# Entity
# Afghanistan             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa (WHO)            NaN   NaN   NaN   NaN   NaN   0.0   0.0   0.0   0.0
# Albania                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Western Pacific (WHO)   NaN   NaN   NaN   NaN   NaN   0.0   0.0   0.0   0.0
# World                   NaN   NaN   NaN   NaN   NaN   0.0   0.0   0.0   0.0
# Yemen                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zimbabwe                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# Year                   1989  ...      2015     2016      2017      2018  \
# Entity                       ...
# Afghanistan             NaN  ...  64.00000  66.0000  64.00000  68.00000
# Africa                  NaN  ...  73.06001  75.6542  75.96257  77.12731
# Africa (WHO)            0.0  ...  70.00000  73.0000  74.00000  75.00000
# Albania                 NaN  ...  99.00000  99.0000  99.00000  99.00000
# Algeria                 NaN  ...  95.00000  91.0000  91.00000  91.00000
# ...                     ...  ...       ...      ...       ...       ...
# Western Pacific (WHO)   1.0  ...  92.00000  93.0000  93.00000  91.00000
# World                   0.0  ...  83.00000  84.0000  84.00000  84.00000
# Yemen                   NaN  ...  63.00000  63.0000  59.00000  54.00000
# Zambia                  NaN  ...  90.00000  95.0000  94.00000  90.00000
# Zimbabwe                NaN  ...  87.00000  90.0000  89.00000  89.00000
#
# Year                       2019       2020      2021      2022      2023  2024
# Entity
# Afghanistan            65.00000  61.000000  55.00000  58.00000  60.00000  59.0
# Africa                 78.16292  75.550385  74.67232  74.55958  75.89457   NaN
# Africa (WHO)           76.00000  74.000000  73.00000  72.00000  75.00000  76.0
# Albania                99.00000  98.000000  98.00000  97.00000  97.00000  97.0
# Algeria                88.00000  84.000000  81.00000  77.00000  94.00000  92.0
# ...                         ...        ...       ...       ...       ...   ...
# Western Pacific (WHO)  95.00000  95.000000  92.00000  94.00000  90.00000  91.0
# World                  86.00000  83.000000  81.00000  84.00000  84.00000  84.0
# Yemen                  60.00000  57.000000  56.00000  58.00000  46.00000  42.0
# Zambia                 88.00000  84.000000  91.00000  92.00000  90.00000  91.0
# Zimbabwe               90.00000  86.000000  88.00000  90.00000  90.00000  91.0
#
# [218 rows x 45 columns]

# %%
df3_pivot = df1.pivot(index='Entity', columns='Year', values='Share of one-year-olds vaccinated against Haemophilus influenzae type b')
df3_pivot.head(1000000)
# Out:
# Year                   1980  1981  1982  1983  1984  1985  1986  1987  1988  \
# Entity
# Afghanistan             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa (WHO)            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Western Pacific (WHO)   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# World                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yemen                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zimbabwe                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# Year                   1989  ...      2015      2016      2017      2018  \
# Entity                       ...
# Afghanistan             NaN  ...  64.00000  66.00000  64.00000  68.00000
# Africa                  NaN  ...  73.06435  75.66934  75.96544  77.12595
# Africa (WHO)            NaN  ...  70.00000  73.00000  74.00000  75.00000
# Albania                 NaN  ...  99.00000  99.00000  99.00000  99.00000
# Algeria                 NaN  ...  95.00000  91.00000  91.00000  91.00000
# ...                     ...  ...       ...       ...       ...       ...
# Western Pacific (WHO)   NaN  ...  26.00000  25.00000  25.00000  26.00000
# World                   NaN  ...  63.00000  70.00000  71.00000  73.00000
# Yemen                   NaN  ...  63.00000  63.00000  59.00000  54.00000
# Zambia                  NaN  ...  90.00000  95.00000  94.00000  90.00000
# Zimbabwe                NaN  ...  87.00000  90.00000  89.00000  89.00000
#
# Year                       2019     2020      2021      2022      2023  2024
# Entity
# Afghanistan            65.00000  61.0000  55.00000  58.00000  60.00000  59.0
# Africa                 78.16157  75.5128  74.67649  74.55958  75.85002   NaN
# Africa (WHO)           76.00000  74.0000  73.00000  72.00000  75.00000  76.0
# Albania                99.00000  98.0000  98.00000  97.00000  97.00000  97.0
# Algeria                88.00000  84.0000  81.00000  77.00000  92.00000  92.0
# ...                         ...      ...       ...       ...       ...   ...
# Western Pacific (WHO)  27.00000  30.0000  30.00000  34.00000  33.00000  34.0
# World                  74.00000  72.0000  72.00000  77.00000  77.00000  78.0
# Yemen                  60.00000  57.0000  56.00000  58.00000  46.00000  42.0
# Zambia                 88.00000  84.0000  91.00000  92.00000  90.00000  91.0
# Zimbabwe               90.00000  86.0000  88.00000  90.00000  90.00000  91.0
#
# [218 rows x 45 columns]

# %%
#df4_pivot = df1.pivot(index='Entity', columns='Year', values='Share of one-year-olds who have had three doses of the hepatitis B vaccine' and 'Share of one-year-olds vaccinated against Haemophilus influenzae type b')
                    
#df4_pivot.head(100)

merge_df = pd.merge(df1, df2, on=['Entity', 'Year'])
rename_df = merge_df.rename(columns={'Share of one-year-olds who have had three doses of the hepatitis B vaccine': 'Hepatitis B Vaccine Coverage','Share of one-year-olds vaccinated against Haemophilus influenzae type b': 'Hib Vaccine Coverage','Share of one-year-olds who have had the one dose of the inactivated polio vaccine': 'Inactivated Polio Vaccine Coverage','Share of one-year-olds who have had one dose of the measles vaccine': 'Measles Vaccine Coverage','Share of one-year-olds who have had the third dose of the pneumococcal conjugate vaccine': 'Pneumococcal Conjugate Vaccine Coverage','Share of one-year-olds who have had three doses of the polio vaccine': 'Polio Vaccine Coverage','Share of one-year-olds vaccinated against rubella': 'Rubella Vaccine Coverage','Share of one-year-olds vaccinated against rotavirus': 'Rotavirus Vaccine Coverage','Share of one-year-olds who have had three doses of the diphtheria, tetanus and pertussis vaccine': 'Di te per Vaccine Coverage','Child mortality rate': 'Child Mortality Rate'})
rename_df
# Out:
#            Entity Code_x  Year  Hepatitis B Vaccine Coverage  \
# 0     Afghanistan    AFG  2007                          63.0
# 1     Afghanistan    AFG  2008                          64.0
# 2     Afghanistan    AFG  2009                          63.0
# 3     Afghanistan    AFG  2010                          66.0
# 4     Afghanistan    AFG  2011                          68.0
# ...           ...    ...   ...                           ...
# 8407     Zimbabwe    ZWE  1990                           NaN
# 8408     Zimbabwe    ZWE  1991                           NaN
# 8409     Zimbabwe    ZWE  1992                           NaN
# 8410     Zimbabwe    ZWE  1993                           NaN
# 8411     Zimbabwe    ZWE  1994                           NaN
#
#       Hib Vaccine Coverage  Inactivated Polio Vaccine Coverage  \
# 0                      NaN                                 NaN
# 1                      NaN                                 NaN
# 2                     63.0                                 NaN
# 3                     66.0                                 NaN
# 4                     68.0                                 NaN
# ...                    ...                                 ...
# 8407                   NaN                                 NaN
# 8408                   NaN                                 NaN
# 8409                   NaN                                 NaN
# 8410                   NaN                                 NaN
# 8411                   NaN                                 NaN
#
#       Measles Vaccine Coverage  Pneumococcal Conjugate Vaccine Coverage  \
# 0                         55.0                                      NaN
# 1                         59.0                                      NaN
# 2                         60.0                                      NaN
# 3                         62.0                                      NaN
# 4                         64.0                                      NaN
# ...                        ...                                      ...
# 8407                      87.0                                      NaN
# 8408                      87.0                                      NaN
# 8409                      86.0                                      NaN
# 8410                      86.0                                      NaN
# 8411                      87.0                                      NaN
#
#       Polio Vaccine Coverage  Rubella Vaccine Coverage  \
# 0                       63.0                       NaN
# 1                       64.0                       NaN
# 2                       63.0                       NaN
# 3                       66.0                       NaN
# 4                       68.0                       NaN
# ...                      ...                       ...
# 8407                    89.0                       NaN
# 8408                    88.0                       NaN
# 8409                    86.0                       NaN
# 8410                    85.0                       NaN
# 8411                    87.0                       NaN
#
#       Rotavirus Vaccine Coverage  Di te per Vaccine Coverage Code_y  \
# 0                            NaN                        63.0    AFG
# 1                            NaN                        64.0    AFG
# 2                            NaN                        63.0    AFG
# 3                            NaN                        66.0    AFG
# 4                            NaN                        68.0    AFG
# ...                          ...                         ...    ...
# 8407                         NaN                        88.0    ZWE
# 8408                         NaN                        87.0    ZWE
# 8409                         NaN                        86.0    ZWE
# 8410                         NaN                        85.0    ZWE
# 8411                         NaN                        87.0    ZWE
#
#       Child Mortality Rate
# 0                    10.07
# 1                     9.63
# 2                     9.22
# 3                     8.83
# 4                     8.46
# ...                    ...
# 8407                  7.97
# 8408                  8.33
# 8409                  8.73
# 8410                  9.16
# 8411                  9.52
#
# [8412 rows x 14 columns]

# %%
#df2_pivot = df2.pivot(index='Entity', columns='Year', values='Child mortality rate')
#df2_pivot.head(100000)

# %%
df2_pivot = df2.pivot(index='Entity', columns='Year', values='Child mortality rate')
df2_pivot.head(100000)
# Out:
# Year         1751  1752  1753  1754  1755  1756  1757  1758  1759  1760  ...  \
# Entity                                                                   ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Africa        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# Vietnam       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# World         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Yemen         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Zambia        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Zimbabwe      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# Year         2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# Entity
# Afghanistan  7.51  7.24  7.00  6.76  6.54  6.33  6.13  5.93  5.74  5.55
# Africa       7.68  7.49  7.31  7.17  6.83  6.66  6.43  6.27  6.22  5.91
# Albania      0.99  0.96  0.94  0.93  0.93  0.94  0.94  0.95  0.94  0.94
# Algeria      2.54  2.49  2.45  2.40  2.37  2.33  2.29  2.26  2.23  2.20
# Andorra      0.37  0.35  0.34  0.32  0.31  0.30  0.29  0.28  0.27  0.26
# ...           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# Vietnam      2.22  2.20  2.18  2.15  2.14  2.12  2.10  2.07  2.04  2.00
# World        4.49  4.37  4.24  4.13  4.02  3.95  3.87  3.82  3.82  3.67
# Yemen        4.84  4.90  4.77  4.66  4.70  4.59  4.32  4.24  4.08  3.93
# Zambia       6.38  6.15  5.90  5.61  5.52  5.41  5.24  4.92  4.67  4.47
# Zimbabwe     6.18  5.98  5.69  5.50  5.23  5.11  5.01  4.76  4.60  4.42
#
# [213 rows x 273 columns]

# %%
#df5_pivot = rename_df.pivot(index = 'Entity', columns='Year', values='Child Mortality Rate' and 'Hepatitis B Vaccine Coverage' and 'Hib Vaccine Coverage' and 'Inactivated Polio Vaccine Coverage' and 'Polio Vaccine Coverage' and 'Measles Vaccine Coverage' and 'Pneumococcal Conjugate Vaccine Coverage' and 'Rubella Vaccine Coverage' and 'Rotavirus Vaccine Coverage' and 'Di te per Vaccine Coverage')
#df5_pivot.head(100000)

# %% [markdown]
# ## 3. Statistik der Roh-Daten (Analyse im Long-Format)
#
# Über die einzelnen Spalten kann folgendes ausgesagt werden:
#
# - Die Spalte *Gebiete* enthält 261 verschieden Gebiete
# - Die Spalte *Codes* enthält 239 verschiedene Codes
# - Es sind Daten zwischen 1543 and 2021 vorhanden. Ab dem Jahr 1950 sind die Daten komplett
# - Die Lebenserwartung streut zwischen 12 und 86.5 Jahren

# %% [markdown]
# ### 3.1 Analyse Länder

# %% [markdown]
# ### 3.2 Analyse Codes

# %% [markdown]
# ### 3.3 Analyse Jahr

# %%
# %pip install matplotlib --upgrade
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.scatterplot(data=rename_df, x='Hepatitis B Vaccine Coverage', y='Child Mortality Rate', hue='Year', palette='viridis')
plt.title('Hepatitis B Vaccine Coverage vs Child Mortality Rate')
plt.xlabel('Hepatitis B Vaccine Coverage (%)')
plt.ylabel('Child Mortality Rate (per 1,000 live births)')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Erstelle ein Streudiagramm, das die Beziehung zwischen Hepatitis-B-Impfstoffabdeckung und Kindersterblichkeitsrate zeigt
# %pip install matplotlib --upgrade
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))

sns.scatterplot(data=rename_df, x='Hib Vaccine Coverage', y='Child Mortality Rate', hue='Year', palette='viridis')
plt.title('Hib Vaccine Coverage vs Child Mortality Rate')
plt.xlabel('Hib Vaccine Coverage (%)')
plt.ylabel('Child Mortality Rate (per 1,000 live births)')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Erstelle ein Streudiagramm, das die Beziehung zwischen Hib-Impfstoffabdeckung und Kindersterblichkeitsrate zeigt
# %pip install matplotlib --upgrade
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.scatterplot(data=rename_df, x='Measles Vaccine Coverage', y='Child Mortality Rate', hue='Year', palette='viridis')
plt.title('Measles Vaccine Coverage vs Child Mortality Rate')
plt.xlabel('Measles Vaccine Coverage (%)')
plt.ylabel('Child Mortality Rate (per 1,000 live births)')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Erstelle ein Streudiagramm, das die Beziehung zwischen Masern-Impfstoffabdeckung und Kindersterblichkeitsrate zeigt
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Zugriff verweigert: 'c:\\users\\brigi\\anaconda3\\lib\\site-packages\\matplotlib\\backends\\_backend_agg.cp313-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: matplotlib in c:\users\brigi\anaconda3\lib\site-packages (3.10.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\brigi\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\brigi\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 836.0 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/8.1 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.1 MB 1.4 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.1 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.9 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().run_line_magic('pip', 'install matplotlib --upgrade')
# ----> 2 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(10,6))
#       4 sns.scatterplot(data=rename_df, x='Hepatitis B Vaccine Coverage', y='Child Mortality Rate', hue='Year', palette='viridis')
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
#      25 from matplotlib import _api, cbook
# ---> 26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
#
# File c:\Users\brigi\anaconda3\Lib\site-packages\matplotlib\backends\__init__.py:1
# ----> 1 from .registry import BackendFilter, backend_registry  # noqa: F401
#       3 # NOTE: plt.switch_backend() (called at import time) will add a "backend"
#       4 # attribute here for backcompat.
#       5 _QT_FORCE_QT5_BINDING = False
#
# ModuleNotFoundError: No module named 'matplotlib.backends.registry'

# %%
scipy.stats
import scipy.stats as stats
from scipy.stats import pearsonr
correlation, p_value = pearsonr(rename_df['Hepatitis B Vaccine Coverage'], rename_df['Child Mortality Rate'])
print(f'Pearson correlation coefficient: {correlation}, P-value: {p_value}')
import scipy.stats as stats
from scipy.stats import pearsonr
correlation, p_value = pearsonr(rename_df['Hib Vaccine Coverage'], rename_df['Child Mortality Rate'])
print(f'Pearson correlation coefficient: {correlation}, P-value: {p_value}')
import scipy.stats as stats
from scipy.stats import pearsonr
correlation, p_value = pearsonr(rename_df['Inactivated Polio Vaccine Coverage'], rename_df['Child Mortality Rate'])
print(f'Pearson correlation coefficient: {correlation}, P-value: {p_value}')
scipy.stats.chisquare
import scipy.stats as stats
from scipy.stats import pearsonr
correlation, p_value = pearsonr(rename_df['Measles Vaccine Coverage'], rename_df['Child Mortality Rate'])
print(f'Pearson correlation coefficient: {correlation}, P-value: {p_value}')
import scipy.stats as stats
from scipy.stats import pearsonr
correlation, p_value = pearsonr(rename_df['Pneumococcal Conjugate Vaccine Coverage'], rename_df['Child Mortality Rate'])
scipy.stats.chi2_contingency
print(f'Pearson correlation coefficient: {correlation}, P-value: {p_value}')
import scipy.stats as stats
from scipy.stats import pearsonr
correlation, p_value = pearsonr(rename_df['Polio Vaccine Coverage'], rename_df['Child Mortality Rate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 scipy.stats
#       2 import scipy.stats as stats
#       3 from scipy.stats import pearsonr
#
# NameError: name 'scipy' is not defined

# %% [markdown]
# ### 3.4 Analyse Durchimpfungsrate

# %% [markdown]
# ## 4. Analyse
# ### Vorgehen
# ### Beobachtungen
# ### Interpretation
